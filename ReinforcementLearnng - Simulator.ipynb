# %% [markdown]
# <h2>Reinforcement learning - Simulator of the environment</h2>

# %%
import numpy as np
from math import *
import matplotlib as plt
import matplotlib
import random

novo_stanje = 'a1'
while(True):
    smer = input()
    br = random.randint(1, 100)
    
    ############### A1
    if(novo_stanje == 'a1'):
        if(smer == 'gore' and br >= 1 and br <= 60):
            epizoda_gotova = False
            novo_stanje = 'a1'
            nagrada = 0
            print(epizoda_gotova, novo_stanje, nagrada)
            continue
        if(smer == 'gore' and br >= 61 and br <= 80): #greska-levo
            epizoda_gotova = False
            novo_stanje = 'a1'
            nagrada = 0
            print(epizoda_gotova, novo_stanje, nagrada)
            continue
        if(smer == 'gore' and br >= 81 and br <= 100): #greska-desno
            epizoda_gotova = False
            novo_stanje = 'a2'
            nagrada = 0
            print(epizoda_gotova, novo_stanje, nagrada)
            continue

        if(smer == 'dole' and br >= 1 and br <= 60):
            epizoda_gotova = True
            novo_stanje = 'a1' #vrati u pocetno stanje
            nagrada = -1
            print(epizoda_gotova, novo_stanje, nagrada)
            continue
        if(smer == 'dole' and br >= 61 and br <= 80): #greska-levo
            epizoda_gotova = False
            novo_stanje = 'a1'
            nagrada = 0
            print(epizoda_gotova, novo_stanje, nagrada)
            continue
        if(smer == 'dole' and br >= 81 and br <= 100): #greska-desno
            epizoda_gotova = False
            novo_stanje = 'a2'
            nagrada = 0
            print(epizoda_gotova, novo_stanje, nagrada)
            continue

        if(smer == 'levo' and br >= 1 and br <= 60):
            epizoda_gotova = False
            novo_stanje = 'a1'
            nagrada = 0
            print(epizoda_gotova, novo_stanje, nagrada)
            continue
        if(smer == 'levo' and br >= 61 and br <= 80): #greska-levo
            epizoda_gotova = True
            novo_stanje = 'a1'
            nagrada = -1
            print(epizoda_gotova, novo_stanje, nagrada)
            continue
        if(smer == 'levo' and br >= 81 and br <= 100): #greska-desno
            epizoda_gotova = False
            novo_stanje = 'a1'
            nagrada = 0
            print(epizoda_gotova, novo_stanje, nagrada)
            continue

        if(smer == 'desno' and br >= 1 and br <= 60):
            epizoda_gotova = False
            novo_stanje = 'a2'
            nagrada = 0
            print(epizoda_gotova, novo_stanje, nagrada)
            continue
        if(smer == 'desno' and br >= 61 and br <= 80): #greska-levo
            epizoda_gotova = False
            novo_stanje = 'a1'
            nagrada = 0
            print(epizoda_gotova, novo_stanje, nagrada)
            continue
        if(smer == 'desno' and br >= 81 and br <= 100): #greska-desno
            epizoda_gotova = True
            novo_stanje = 'a1'
            nagrada = -1
            print(epizoda_gotova, novo_stanje, nagrada)
            continue
        
    ################ A2
    if(novo_stanje == 'a2'):
        if(smer == 'gore' and br >= 1 and br <= 60):
            epizoda_gotova = False
            novo_stanje = 'a2'
            nagrada = 0
            print(epizoda_gotova, novo_stanje, nagrada)
            continue
        if(smer == 'gore' and br >= 61 and br <= 80): #greska-levo
            epizoda_gotova = False
            novo_stanje = 'a1'
            nagrada = 0
            print(epizoda_gotova, novo_stanje, nagrada)
            continue
        if(smer == 'gore' and br >= 81 and br <= 100): #greska-desno
            epizoda_gotova = False
            novo_stanje = 'a3'
            nagrada = 0
            print(epizoda_gotova, novo_stanje, nagrada)
            continue

        if(smer == 'dole' and br >= 1 and br <= 60):
            epizoda_gotova = False
            novo_stanje = 'a2'
            nagrada = 0
            print(epizoda_gotova, novo_stanje, nagrada)
            continue
        if(smer == 'dole' and br >= 61 and br <= 80): #greska-levo
            epizoda_gotova = False
            novo_stanje = 'a1'
            nagrada = 0
            print(epizoda_gotova, novo_stanje, nagrada)
            continue
        if(smer == 'dole' and br >= 81 and br <= 100): #greska-desno
            epizoda_gotova = False
            novo_stanje = 'a3'
            nagrada = 0
            print(epizoda_gotova, novo_stanje, nagrada)
            continue

        if(smer == 'levo' and br >= 1 and br <= 60):
            epizoda_gotova = False
            novo_stanje = 'a1'
            nagrada = 0
            print(epizoda_gotova, novo_stanje, nagrada)
            continue
        if(smer == 'levo' and br >= 61 and br <= 80): #greska-levo
            epizoda_gotova = False
            novo_stanje = 'a2'
            nagrada = 0
            print(epizoda_gotova, novo_stanje, nagrada)
            continue
        if(smer == 'levo' and br >= 81 and br <= 100): #greska-desno
            epizoda_gotova = False
            novo_stanje = 'a2'
            nagrada = 0
            print(epizoda_gotova, novo_stanje, nagrada)
            continue

        if(smer == 'desno' and br >= 1 and br <= 60):
            epizoda_gotova = False
            novo_stanje = 'a3'
            nagrada = 0
            print(epizoda_gotova, novo_stanje, nagrada)
            continue
        if(smer == 'desno' and br >= 61 and br <= 80): #greska-levo
            epizoda_gotova = False
            novo_stanje = 'a2'
            nagrada = 0
            print(epizoda_gotova, novo_stanje, nagrada)
            continue
        if(smer == 'desno' and br >= 81 and br <= 100): #greska-desno
            epizoda_gotova = False
            novo_stanje = 'a2'
            nagrada = 0
            print(epizoda_gotova, novo_stanje, nagrada)
            continue
        
    ############## A3
    if(novo_stanje == 'a3'):
        if(smer == 'gore' and br >= 1 and br <= 60):
            epizoda_gotova = False
            novo_stanje = 'a3'
            nagrada = 0
            print(epizoda_gotova, novo_stanje, nagrada)
            continue
        if(smer == 'gore' and br >= 61 and br <= 80): #greska-levo
            epizoda_gotova = False
            novo_stanje = 'a2'
            nagrada = 0
            print(epizoda_gotova, novo_stanje, nagrada)
            continue
        if(smer == 'gore' and br >= 81 and br <= 100): #greska-desno
            epizoda_gotova = False
            novo_stanje = 'a4'
            nagrada = 0
            print(epizoda_gotova, novo_stanje, nagrada)
            continue

        if(smer == 'dole' and br >= 1 and br <= 60):
            epizoda_gotova = True
            novo_stanje = 'a1' #vrati u pocetno stanje
            nagrada = -1
            print(epizoda_gotova, novo_stanje, nagrada)
            continue
        if(smer == 'dole' and br >= 61 and br <= 80): #greska-levo
            epizoda_gotova = False
            novo_stanje = 'a2'
            nagrada = 0
            print(epizoda_gotova, novo_stanje, nagrada)
            continue
        if(smer == 'dole' and br >= 81 and br <= 100): #greska-desno
            epizoda_gotova = False
            novo_stanje = 'a4'
            nagrada = 0
            print(epizoda_gotova, novo_stanje, nagrada)
            continue

        if(smer == 'levo' and br >= 1 and br <= 60):
            epizoda_gotova = False
            novo_stanje = 'a2'
            nagrada = 0
            print(epizoda_gotova, novo_stanje, nagrada)
            continue
        if(smer == 'levo' and br >= 61 and br <= 80): #greska-levo
            epizoda_gotova = True
            novo_stanje = 'a1'
            nagrada = -1
            print(epizoda_gotova, novo_stanje, nagrada)
            continue
        if(smer == 'levo' and br >= 81 and br <= 100): #greska-desno
            epizoda_gotova = False
            novo_stanje = 'a3'
            nagrada = 0
            print(epizoda_gotova, novo_stanje, nagrada)
            continue

        if(smer == 'desno' and br >= 1 and br <= 60):
            epizoda_gotova = False
            novo_stanje = 'a4'
            nagrada = 0
            print(epizoda_gotova, novo_stanje, nagrada)
            continue
        if(smer == 'desno' and br >= 61 and br <= 80): #greska-levo
            epizoda_gotova = False
            novo_stanje = 'a3'
            nagrada = 0
            print(epizoda_gotova, novo_stanje, nagrada)
            continue
        if(smer == 'desno' and br >= 81 and br <= 100): #greska-desno
            epizoda_gotova = True
            novo_stanje = 'a1'
            nagrada = -1
            print(epizoda_gotova, novo_stanje, nagrada)
            continue
    
    ################# A4
    if(novo_stanje == 'a4'):
        if(smer == 'gore' and br >= 1 and br <= 60):
            epizoda_gotova = False
            novo_stanje = 'a4'
            nagrada = 0
            print(epizoda_gotova, novo_stanje, nagrada)
            continue
        if(smer == 'gore' and br >= 61 and br <= 80): #greska-levo
            epizoda_gotova = False
            novo_stanje = 'a3'
            nagrada = 0
            print(epizoda_gotova, novo_stanje, nagrada)
            continue
        if(smer == 'gore' and br >= 81 and br <= 100): #greska-desno
            epizoda_gotova = False
            novo_stanje = 'a5'
            nagrada = 0
            print(epizoda_gotova, novo_stanje, nagrada)
            continue

        if(smer == 'dole' and br >= 1 and br <= 60):
            epizoda_gotova = False
            novo_stanje = 'a4'
            nagrada = 0
            print(epizoda_gotova, novo_stanje, nagrada)
            continue
        if(smer == 'dole' and br >= 61 and br <= 80): #greska-levo
            epizoda_gotova = False
            novo_stanje = 'a3'
            nagrada = 0
            print(epizoda_gotova, novo_stanje, nagrada)
            continue
        if(smer == 'dole' and br >= 81 and br <= 100): #greska-desno
            epizoda_gotova = False
            novo_stanje = 'a5'
            nagrada = 0
            print(epizoda_gotova, novo_stanje, nagrada)
            continue

        if(smer == 'levo' and br >= 1 and br <= 60):
            epizoda_gotova = False
            novo_stanje = 'a3'
            nagrada = 0
            print(epizoda_gotova, novo_stanje, nagrada)
            continue
        if(smer == 'levo' and br >= 61 and br <= 80): #greska-levo
            epizoda_gotova = False
            novo_stanje = 'a4'
            nagrada = 0
            print(epizoda_gotova, novo_stanje, nagrada)
            continue
        if(smer == 'levo' and br >= 81 and br <= 100): #greska-desno
            epizoda_gotova = False
            novo_stanje = 'a4'
            nagrada = 0
            print(epizoda_gotova, novo_stanje, nagrada)
            continue

        if(smer == 'desno' and br >= 1 and br <= 60):
            epizoda_gotova = False
            novo_stanje = 'a5'
            nagrada = 0
            print(epizoda_gotova, novo_stanje, nagrada)
            continue
        if(smer == 'desno' and br >= 61 and br <= 80): #greska-levo
            epizoda_gotova = False
            novo_stanje = 'a4'
            nagrada = 0
            print(epizoda_gotova, novo_stanje, nagrada)
            continue
        if(smer == 'desno' and br >= 81 and br <= 100): #greska-desno
            epizoda_gotova = False
            novo_stanje = 'a4'
            nagrada = 0
            print(epizoda_gotova, novo_stanje, nagrada)
            continue

    ################## A5
    if(novo_stanje == 'a5'):
        if(smer == 'gore' and br >= 1 and br <= 60):
            epizoda_gotova = False
            novo_stanje = 'a5'
            nagrada = 0
            print(epizoda_gotova, novo_stanje, nagrada)
            continue
        if(smer == 'gore' and br >= 61 and br <= 80): #greska-levo
            epizoda_gotova = False
            novo_stanje = 'a4'
            nagrada = 0
            print(epizoda_gotova, novo_stanje, nagrada)
            continue
        if(smer == 'gore' and br >= 81 and br <= 100): #greska-desno
            epizoda_gotova = False
            novo_stanje = 'a5'
            nagrada = 0
            print(epizoda_gotova, novo_stanje, nagrada)
            continue

        if(smer == 'dole' and br >= 1 and br <= 60):
            epizoda_gotova = True
            novo_stanje = 'a1' #vrati u pocetno stanje
            nagrada = 3
            print(epizoda_gotova, novo_stanje, nagrada)
            continue
        if(smer == 'dole' and br >= 61 and br <= 80): #greska-levo
            epizoda_gotova = False
            novo_stanje = 'a4'
            nagrada = 0
            print(epizoda_gotova, novo_stanje, nagrada)
            continue
        if(smer == 'dole' and br >= 81 and br <= 100): #greska-desno
            epizoda_gotova = False
            novo_stanje = 'a5'
            nagrada = 0
            print(epizoda_gotova, novo_stanje, nagrada)
            continue

        if(smer == 'levo' and br >= 1 and br <= 60):
            epizoda_gotova = False
            novo_stanje = 'a4'
            nagrada = 0
            print(epizoda_gotova, novo_stanje, nagrada)
            continue
        if(smer == 'levo' and br >= 61 and br <= 80): #greska-levo
            epizoda_gotova = True
            novo_stanje = 'a1'
            nagrada = 3
            print(epizoda_gotova, novo_stanje, nagrada)
            continue
        if(smer == 'levo' and br >= 81 and br <= 100): #greska-desno
            epizoda_gotova = False
            novo_stanje = 'a5'
            nagrada = 0
            print(epizoda_gotova, novo_stanje, nagrada)
            continue

        if(smer == 'desno' and br >= 1 and br <= 60):
            epizoda_gotova = False
            novo_stanje = 'a5'
            nagrada = 0
            print(epizoda_gotova, novo_stanje, nagrada)
            continue
        if(smer == 'desno' and br >= 61 and br <= 80): #greska-levo
            epizoda_gotova = False
            novo_stanje = 'a5'
            nagrada = 0
            print(epizoda_gotova, novo_stanje, nagrada)
            continue
        if(smer == 'desno' and br >= 81 and br <= 100): #greska-desno
            epizoda_gotova = True
            novo_stanje = 'a1'
            nagrada = 3
            print(epizoda_gotova, novo_stanje, nagrada)
            continue
